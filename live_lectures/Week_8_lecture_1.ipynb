# %% [markdown]
# # Data Analysis with Visualization
# ## Topics Covered
# + Data visualization libraries in Python
# + Performance Exploratory Data Analysis (EDA) with Seaborn and pandas
# + Making missing value plots
# + Python visualization best practices

# %% [markdown]
# # Data visualization libraries in Python
# + The original-level plotting package in Python is [matplotlib](https://matplotlib.org/)
# + For plotting complex plots such as time series, interactive plots, text annotation, and plots/figure combinations, we can use higher-level packages such as [Seaborn](https://seaborn.pydata.org/), [Plotly](https://plotly.com/python/), [Bokeh](https://docs.bokeh.org/en/latest/), [plotnine](https://plotnine.readthedocs.io/en/stable/), [Holoviz](https://holoviz.org/), etc.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## EVOLUTION based graphs
# + Line chart
# + Area chart
# + Stacked area chart

# %% [markdown]
# ## Line chart using pyplot
# Information as a series of data points connected by straight line segments.
#
# ```python
# # libraries
# import matplotlib.pyplot as plt
# import numpy as np
# #
# ## create data
# t = np.arange(0.0, 5.0, 0.01)
# s = 1 + np.sin(2 * np.pi * t)
# #
# plt.plot(s)
# plt.show()
# plt.savefig('line.png')
#
#
# ```
#
# matplotlib.pyplot is a collection of command-style functions for graphical plotting. Each pyplot function can create a figure, a plotting area in a figure, and decorates the plot with labels, etc.

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
#
## create data
t = np.arange(0.0, 5.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)
#
plt.plot(s)
plt.show()
plt.savefig('line.png')

# %% [markdown]
# ## Line chart using seaborn
#  Information as a series of data points connected by straight line segments.

# %%
# libraries
import numpy as np
import seaborn as sns
sns.set()

# create data
t = np.arange(0.0, 5.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

# use the plot function
sns.lineplot(data=s)
# Out:
# <Axes: >

# %% [markdown]
# ## Set multiple properties on a list of lines
#
# ```python
# import numpy as np
#
# # evenly sampled time at 200ms intervals
# t = np.arange(1., 10., .5)
#
# # red dashes, blue squares and green triangles
# plt.plot(t, t*3, 'r--', t, t**2+t, 'bs', t, t**3, 'g^')
# plt.show()
#
# ```

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(1., 10., .5)

# red dashes, blue squares and green triangles
plt.plot(t, t*3, 'r--', t, t**2+t, 'bs', t, t**3, 'g^')
plt.show()

# %% [markdown]
# # Creating multiple subplots
# **pyplot.subplots** creates a figure and a grid of subplots with a single call, while providing reasonable control over how the individual plots are created.
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Some example data to display
# x = np.linspace(0, 2 * np.pi, 400)
# y = np.sin(x ** 2)
#
# fig, axs = plt.subplots(2)
# fig.suptitle('Vertically stacked subplots')
# axs[0].plot(x, y)
# axs[1].plot(x, -y)
#
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

fig, axs = plt.subplots(2)
fig.suptitle('Vertically stacked subplots')
axs[0].plot(x, y)
axs[1].plot(x, -y)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Horizontally stacked subplots')
ax1.plot(x, y)
ax2.plot(x, -y)

# %% [markdown]
# # Area chart
# The area between the x axis and the line is filled in with color.
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.arange(0.0, 2, 0.01)
# y = np.sin(2 * np.pi * x)
# plt.fill_between( x, y, color="skyblue", alpha=0.6)
# plt.show()
#
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y = np.sin(2 * np.pi * x)
plt.fill_between( x, y, color="skyblue", alpha=0.4)

# %% [markdown]
# ## Stacked area chart
# This is done using the stackplot() function
#
# ```python
# # library
# import numpy as np
# import matplotlib.pyplot as plt
#
# # x and y axis
# x=np.arange(1,6)
# y=[ x+5, np.sqrt(x)*5, x**2 ]
#
# # Basic stacked area chart.
# plt.stackplot(x,y, labels=['A','B','C'])
# plt.legend(loc='upper left')
# ```

# %%
# library
import numpy as np
import matplotlib.pyplot as plt

# x and y axis
x=np.arange(1,6)
y=[ x+5, np.sqrt(x)*5, x**2 ]

# Basic stacked area chart.
plt.stackplot(x,y, labels=['A','B','C'])
plt.legend(loc='upper left')

# %% [markdown]
# # CORRELATION based graphs
# + Scatter plot
# + Bubble plot
# + Heatmap

# %% [markdown]
# # Scatter plot
# + Provide a representation of where each points in the entire dataset are present.
# + Seaborn installation:  pip install seaborn
# + In Jupyter Notebook:  !pip install seaborn
#
# ```python
# # library & dataset
# import seaborn as sns
# sns.set()
#
# df = sns.load_dataset('iris')
#
# # Without regression fit.
# sns.regplot(x=df["sepal_length"], y=df["sepal_width"], fit_reg=False)
#
# ```

# %%
# library & dataset
import seaborn as sns
sns.set()

df = sns.load_dataset('iris')
df
# Without regression fit.
#sns.regplot(x=df["sepal_length"], y=df["sepal_width"], fit_reg=False)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# library & dataset
import seaborn as sns
sns.set()

df = sns.load_dataset('iris')

# Without regression fit.
sns.regplot(x=df["sepal_length"], y=df["sepal_width"], fit_reg=False)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# + Use categorical variable to color scatterplot using seaborn.
#
# ```python
# # library & dataset
# import seaborn as sns
# df = sns.load_dataset('iris')
#
# # Use the 'hue' argument to provide a factor variable
# sns.lmplot( x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=False)
#
# # Move the legend to an empty part of the plot
# plt.legend(loc='lower right')
#
# ```

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=True)

# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %% [markdown]
# + Make makers per group
#
# ```python
#
# # library & dataset
# import seaborn as sns
# df = sns.load_dataset('iris')
#
# # give a list to the marker argument
# sns.lmplot( x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=False, markers=["o", "x", "1"])
#
# # Move the legend to an empty part of the plot
# plt.legend(loc='lower right')
#
# ```

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

# give a list to the marker argument
sns.lmplot( x="sepal_length", y="sepal_width", data=df, fit_reg=False, hue='species', legend=False, markers=["o", "x", "1"])

# Move the legend to an empty part of the plot
plt.legend(loc='lower right')

# %% [markdown]
# # Single Hue Sequential color Scale
#
# ```python
# # Libraries
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
#
# # create data
# num_sample = 100
# x = np.random.rand(num_sample)
# y = x+np.random.rand(num_sample)
# z = x+np.random.rand(num_sample)
# df = pd.DataFrame({'x':x, 'y':y, 'z':z})
#
# # Plot with palette
# sns.lmplot( x='x', y='y', data=df, fit_reg=False, hue='x', legend=False, palette="Reds")
#
# ```

# %%
# Libraries
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# create data
num_sample = 100
x = np.random.rand(num_sample)
y = x+np.random.rand(num_sample)
z = x+np.random.rand(num_sample)
df = pd.DataFrame({'x':x, 'y':y, 'z':z})

# Plot with palette
sns.lmplot( x='x', y='y', data=df, fit_reg=True, hue='x', legend=False, palette="Reds")

# %% [markdown]
# # Diverging Color Scale
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
#
# # create data
# num_sample = 100
# x = np.random.rand(num_sample)
# y = x+np.random.rand(num_sample)
# z = x+np.random.rand(num_sample)
# df = pd.DataFrame({'x':x, 'y':y, 'z':z})
#
# # plot
# sns.lmplot( x='x', y='y', data=df, fit_reg=False, hue='x', legend=False, palette="BrBG")
#
# ```

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# create data
num_sample = 100
x = np.random.rand(num_sample)
y = x+np.random.rand(num_sample)
z = x+np.random.rand(num_sample)
df = pd.DataFrame({'x':x, 'y':y, 'z':z})

# plot
sns.lmplot( x='x', y='y', data=df, fit_reg=False, hue='x', legend=False, palette="BrBG")

# %% [markdown]
# # Bubble plot
# + Scattered butt with quantitative information - the area of the circles must be proportional to the value.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# N = 30
# x = np.random.rand(N)
# y = np.random.rand(N)
# colors = np.random.rand(N)
# area = (N*np.random.rand(N))**2
#
# plt.scatter(x, y, s=area, c=colors, alpha=0.5)
# plt.show()
#
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 30
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (N*np.random.rand(N))**2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# # Heat map
# + Graphical representation of data that are represented as colors.
#
# ```python
# # library
# import seaborn as sns
# import pandas as pd
# import numpy as np
#
# # Create a dataset (fake)
# df = pd.DataFrame(np.random.random((20,20)))
#
# # heatmap: a visualization of this square matrix
# p1 = sns.heatmap(df)
# ```

# %%
# library
import seaborn as sns
import pandas as pd
import numpy as np

# Create a dataset (fake)
df = pd.DataFrame(np.random.random((10,10)))

# heatmap: a visualization of this square matrix
p1 = sns.heatmap(df)

# %% [markdown]
# # Hexagon Bin Chart
# + Hexagon is a histogram-like chart where each hexagon represents the density of samples (instead of bars in histogram).
#
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # create data
# x = np.random.normal(size=50000)
# y = (x * 3 + np.random.normal(size=50000)) * 5
#
# # Make the plot
# plt.hexbin(x, y, gridsize=(15,15) )
# plt.show()
#
# # We can control the size of the bins:
# plt.hexbin(x, y, gridsize=(150,150) )
# plt.show()
#
# ```

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
x = np.random.normal(size=50000)
y = (x * 3 + np.random.normal(size=50000)) * 5

# Make the plot
plt.hexbin(x, y, gridsize=(15,15) )
plt.show()

# We can control the size of the bins:
plt.hexbin(x, y, gridsize=(150,150) )
plt.show()

# %% [markdown]
# # DISTRIBUTION based graphs
# + Boxplot
# + Histogram
# + Violin

# %% [markdown]
# ## Boxplot
# + The line that divides the box into 2 parts:
#  + the median of the data
#  + the end of the box shows the upper and lower quartiles.
#  + The outliers
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Boxplot using seaborn
#
# ```python
# # library & dataset
# import seaborn as sns
# df = sns.load_dataset('iris')
# sns.boxplot(x='species', y='sepal_length', data=df)
# ```

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x='species', y='sepal_width', data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>

# %% [markdown]
# ## Histogram
# + Graphical representation of the distribution of numerical data.
#
# ```python
# # Import library and dataset
# import seaborn as sns
# df = sns.load_dataset('iris')
#
# # Control the number of bins
# sns.distplot( df["sepal_length"], bins=20)
# ```

# %%
# Import library and dataset
import seaborn as sns
df = sns.load_dataset('iris')
df
# Control the number of bins
#sns.distplot( df["sepal_length"], bins=20)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.distplot( df["sepal_length"], bins=50)
# Out:
# <ipython-input-52-422f24dcd2d9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df["sepal_length"], bins=50)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# # Violin plot
# + A hybrid of a box plot and a [kernel density plot](https://en.wikipedia.org/wiki/Kernel_density_estimation)
# + Wider sections of the violin plot represent a higher probability.
#
# ```python
# df = sns.load_dataset("titanic")
# sns.violinplot(x=df["age"])
#
# ```

# %%
df = sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.violinplot(x=df["fare"])
# Out:
# <Axes: xlabel='fare'>

# %% [markdown]
# ```python
# # library & dataset
# import seaborn as sns
# df = sns.load_dataset('iris')
#
# # plot
# sns.violinplot( x=df["species"], y=df["sepal_length"] )
#
# ```

# %%
# library & dataset
import seaborn as sns
df = sns.load_dataset('iris')

# plot
sns.violinplot( x=df["species"], y=df["sepal_width"] )
# Out:
# <Axes: xlabel='species', ylabel='sepal_width'>
