# %% [markdown]
# ## Classes and Objects in Python
# Python Classes/Objects
# Python is an object oriented programming language.
#
# Almost everything in Python is an object, with its properties and methods.
#
# A Class is like an object constructor, or a "blueprint" for creating objects.
#
#
# [source](https://www.w3schools.com/python/python_classes.asp)

# %%
class MyClass:
  x = 5

# %%
p1 = MyClass()
print(p1.x)
# Out:
# 5

# %% [markdown]
# **The ``__init__()`` Function**
# The examples above are classes and objects in their simplest form, and are not really useful in real life applications.
#
# To understand the meaning of classes we have to understand the built-in ``__init__()`` function.
#
# All classes have a function called ``__init__()``, which is always executed when the class is being initiated.
#
# Use the ``__init__()`` function to assign values to object properties, or other operations that are necessary to do when the object is being created:
# ![image.png](data:image/png;base64,...)

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1.name)
print(p1.age)
# Out:
# John
# 36

# %% [markdown]
# + A **Class** acts like an object constructor
#   + Classes are essentially a template to create your objects.
# + **Objects**:
#   + An Object is an instance of a Class.
#   + an encapsulation of variables and functions into a single entity.
#   + retrieve their variables and functions from classes.
#   + An object consists of :
#     + **State**: the attributes of an object.
#     + **Behavior**: the methods of an object.
#     + **Identity**: a unique name for an object

# %% [markdown]
# ## **Class Attributes**
# + **Instance variables:** The instance variables are attributes attached to an instance of a class. We define instance variables in the constructor ( the ``__init__()`` method of a class). the value of a variable varies from object to object
# + **Class Variables:** A class variable is a variable that is declared inside of class, but outside of any instance method or ``__init__()`` method.

# %% [markdown]
# # class **Syntax**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Create a class and an object
# + Create a class named MyClass, with a property named x:

# %%
class MyClass:
  x = 20

# %% [markdown]
# Create an object named **obj1**, and print the value of x:

# %%
obj1 = MyClass()
print(obj1.x)
# Out:
# 20

# %% [markdown]
# + Classes are created by keyword class.
# + Attributes are the variables that belong to a class.
# + Attributes are always public and can be accessed using the dot (.) operator.
#   + e.g., MyClass.attribute

# %% [markdown]
# # Declaring Objects (instantiating a class)
# + When an object of a class is created, the class is said to be instantiated.
# + All the instances share the attributes and the behavior of the class.

# %%
class MyClass:
  x = 123

  def func(self):
    return 'hello world'

# %%
obj = MyClass()
obj.x
# Out:
# 123

# %% [markdown]
# ```
# obj = MyClass() ##creates a new instance of the class: an object named by the variable obj.
#
# ```

# %% [markdown]
#  **MyClass.x** and **MyClass.func** are valid attribute references, returning an integer and a function object, respectively.

# %% [markdown]
# # Declaring Objects (instantiating a class)

# %%
class Math:
    # A simple class attribute
    attr1 = "math"
    attr2 = "algebra"

# Object instantiation
obj1 = Math()

# Accessing class attributes
# and method through objects
print(obj1.attr1)
print(obj1.attr2)
# Out:
# math
# algebra

# %% [markdown]
# In this example, an object is created named **obj1**. The class only has two class attributes and the values are math and algebra.

# %% [markdown]
# # **The `__init__()` Function**
# + The __init__() Function
#   + A class typically contains a function called `__init__()`, always executed when the class is being initiated.
#   + Use the `__init__()` function to assign values to object properties.
#
# <font color='green'>Create a class named </font> <font color='blue'>example,</font> <font color='green'>use the</font> `__init__()` <font color='green'>function to assign values for **name** and **number**:</font>

# %%
class example:
  def __init__(self, name, number):
      self.name = name
      self.number = number
  def myfunc(self):
      print("xx " + self.name + self.number)

myob = example(" SAT", str(4310))
myob.myfunc()
# Out:
# xx  SAT4310

# %% [markdown]
# **Note**: The self parameter is a reference to the class instance itself that is used to access class’s variables. It has to be the first parameter of any function in the class.

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1.name)
print(p1.age)

# %% [markdown]
# **Note**: The `__init__()` function is called automatically every time the class is being used to create a new object.

# %% [markdown]
# # **Constructors in Python**
# + It is used to initialize (assign values) to the data members of the class when an object of the class is created.
# + the `__init__()` method is called the constructor when an object is created.
# + ** Types of constructors : **
#   + **default constructor:** doesn’t accept any arguments, and contains only one argument which is a reference to the instance being constructed.
#   + **parameterized constructor: **accepts arguments, and takes its first argument as a reference to the instance being constructed known as self and the rest of the arguments are provided by the user.
# +** Syntax of constructor declaration :**
#
# ```python
# def __init__(self):
#      # body of the constructor
# ```

# %%
# Example of default constructor:
class Python:
  #default constructor
  def __init__(self):
     self.py="Python"
  # a method for printing data members
  def print_Py(self):
    print(self.py)
# creating object of the class
obj=Python()

# calling the instance method using the object obj
obj.print_Py()
# Out:
# Python

# %%
# Example of parameterized constructor:

class Multiplication:
  first=0
  second=0
  answer=0

  #parameterized constructor
  def __init__(self, f, s):
     self.first=f
     self.second=s

  def display(self):
    print("First number= "+str(self.first))
    print("Second number= "+str(self.second))
    print("Multiplication of the two numbers= "+str(self.answer))

  def calculate(self):
    self.answer=self.first*self.second

# creating object of the class
# this will invoke parameterized constructor
obj=Multiplication(100, 500)

# perform multiplication
obj.calculate()

# display result
obj.display()
# Out:
# First number= 100
# Second number= 500
# Multiplication of the two numbers= 50000

# %% [markdown]
# # **The `__str__()` Function**
#
# The `__str__()` function controls what should be returned when the class object is represented as a string.
#
# If the `__str__()` function is not set, the string representation of the object is returned:

# %%
# The string representation of an object WITHOUT the __str__() function:
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("John", 36)

print(p1)

# %%
# The string representation of an object WITH the __str__() function:
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name}({self.age})"

p1 = Person("John", 36)

print(p1)
# Out:
# John(36)

# %% [markdown]
# # **The self Parameter**
# The `self` parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.
#
# It does not have to be named `self` , you can call it whatever you like, but it has to be the first parameter of any function in the class:

# %%
# Use the words mysillyobject and abc instead of self:
class Person:
  def __init__(mysillyobject, name, age):
    mysillyobject.name = name
    mysillyobject.age = age

  def myfunc(abc):
    print("Hello my name is " + abc.name)

p1 = Person("John", 36)
p1.myfunc()

# %% [markdown]
# # Object Methods
# + Objects can also contain methods.
# + Methods in objects are functions that belong to the object.

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def myfunc(self):
    print("Hello my name is " + self.name)
    print("I am" + str(self.age) + " years old.")
obj = Person("Mike", 25)
obj.myfunc()
# Out:
# Hello my name is Mike
# I am25 years old.

# %% [markdown]
# ## Changes in objects
# + Modify Object Properties
# Modify properties on objects:
# ```python
# obj.age = 50
# ```
# + Delete Object Properties
# Delete Object Properties:
# ```python
# del obj.age
# ```
#
# + Delete Objects
# delete objects by using the
# ```python
# del keyword
# ```
#
# **Public Access Modifier**
# + By default the member variables and methods are public which means they can be accessed from anywhere outside or inside the class. No public keyword is required to make the class or methods and properties public.
#
# [source](https://www.tutorialspoint.com/access-modifiers-in-python-public-private-and-protected)

# %% [markdown]
# # Delete Objects
# You can delete objects by using the del keyword:
# ```python
# del p1
# ```

# %% [markdown]
# ## The <font color='blue'>**pass**</font> Statement
# + class definitions cannot be empty, but if you want to have a class definition with no content, put the pass statement to avoid getting an error.

# %%
class School:
  pass

# %%
s1=School()
s1.name="School1"

# %%
s1.name
# Out:
# 'School1'

# %%
del s1

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-d0257f733e5e> in <cell line: 1>()
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %% [markdown]
# # **Class and Instance Variables**
#
# Instance variables are for data, unique to each instance and class variables are for attributes and methods shared by all instances of the class. Instance variables are variables whose value is assigned inside a constructor or method with self whereas class variables are variables whose value is assigned in the class.

# %%
#Defining instance variables using a constructor.

# Python3 program to show that the variables with a value
# assigned in the class declaration, are class variables and
# variables inside methods and constructors are instance
# variables.

# Class for Dog


class Dog:

    # Class Variable
  animal = 'dog'

    # The init method or constructor
  def __init__(self, breed, color):

      # Instance Variable
      self.__breed = breed
      self.color = color

  def getBreed(self):
    return self.__breed

# Objects of Dog class
Rodger = Dog("Pug", "brown")
Buzo = Dog("Bulldog", "black")

print('Rodger details:')
print('Rodger is a', Rodger.animal)
print('Breed: ', Rodger.getBreed)


#print('Color: ', Rodger.color)

##print('\nBuzo details:')
#print('Buzo is a', Buzo.animal)
#print('Breed: ', Buzo.breed)
#print('Color: ', Buzo.color)

# Class variables can be accessed using class
# name also
print("\nAccessing class variable using class name")
print(Dog.animal)
# Out:
# Rodger details:
# Rodger is a dog
# Breed:  <bound method Dog.getBreed of <__main__.Dog object at 0x7ae69526c940>>
#
# Accessing class variable using class name
# dog

# %% [markdown]
# A class named **Dog** is defined with a class variable animal set to the string “dog”. Class variables are shared by all objects of a class and can be accessed using the class name. Dog class has two instance variables breed and color. Later we are creating two objects of the Dog class and we are printing the value of both objects with a class variable named animal.

# %%
# Defining instance variables using the normal method:

# Python3 program to show that we can create
# instance variables inside methods

# Class for Dog


class Dog:

    # Class Variable
    animal = 'dog'

    # The init method or constructor
    def __init__(self, breed):

        # Instance Variable
        self.breed = breed

    # Adds an instance variable
    def setColor(self, color):
        self.color = color

    # Retrieves instance variable
    def getColor(self):
        return self.color


# Driver Code
Rodger = Dog("pug")
Rodger.setColor("brown")
print(Rodger.getColor())
# Out:
# brown

# %% [markdown]
# In this example, We have defined a class named **Dog** and we have created a class variable animal. We have created an instance variable breed in the **constructor**. The class Dog consists of two methods setColor and getColor, they are used for creating and initializing an instance variable and retrieving the value of the instance variable. We have made an object of the **Dog** class and we have set the instance variable value to brown and we are printing the value in the terminal.
