# %% [markdown]
# <h1><center>SAT 4310 Advanced Scripting Programming </center></h1>
#
# <h1><center>Lab 0: Anaconda Setup - Intro to Jupyter </center></h1>

# %% [markdown]
# 👋Hello! Happy new semester!
#
#
# Welcome to the Advance Scripting Programming Lab. This document should familiarize you with Jupyter Lab and creating and editing Jupyter notebooks, something that you're going to be doing quite a lot of over the course of this semester.

# %% [markdown]
# ## Getting familiar
#
# The following exercises are your lab for this week. In future, you'll usually have a pre-made notebook where you'll fill in your answers in code or Markdown cells. For this week, follow these instructions to create your own notebook!

# %% [markdown]
# # **Pre lab**
# # Installing Anaconda Navigator

# %% [markdown]
# ## Installing on Windows [(source)](https://docs.anaconda.com/free/anaconda/install/windows/)
# 1. [Download the Anaconda installer.](https://www.anaconda.com/)
#
# 2. Go to your Downloads folder and double-click the installer to launch. To prevent permission errors, do not launch the installer from the Favorites folder.
#
# 3. Click Next.
#
# 4. Read the licensing terms and click I Agree.
#
# 5. It is recommended that you install for Just Me, which will install Anaconda Distribution to just the current user account. Only select an install for All Users if you need to install for all users’ accounts on the computer (which requires Windows Administrator privileges).
#
# 6. Click Next.
#
# 7. Select a destination folder to install Anaconda and click Next. Install Anaconda to a directory path that does not contain spaces or unicode characters.
#
# 8. Choose whether to add Anaconda to your PATH environment variable or register Anaconda as your default Python. We don’t recommend adding Anaconda to your PATH environment variable, since this can interfere with other software. Unless you plan on installing and running multiple versions of Anaconda or multiple versions of Python, accept the default and leave this box checked. Instead, use Anaconda software by opening Anaconda Navigator or the Anaconda Prompt from the Start Menu.
#
# 9. Click Install. If you want to watch the packages Anaconda is installing, click Show Details.
#
# 10. Click Next.
#
# 11. Optional: To learn more about Anaconda’s cloud notebook service, go to https://www.anaconda.com/code-in-the-cloud.
# Or click Continue to proceed.
#
# 12. After a successful installation you will see the “Thanks for installing Anaconda” dialog box.
#
# You are done, now you can try launching anaconda navigator!

# %% [markdown]
# ## Installing on MacOS
# Please refer to the following link: https://docs.anaconda.com/free/anaconda/install/mac-os/
#
# ## Installing on Linux
# Please refer to the following link: https://docs.anaconda.com/free/anaconda/install/linux/

# %% [markdown]
# ## Adding tools to Anaconda Navigator
#
# For this class we are going to be mostly working using either Juputer Notebook or Google Collaboratory. However, few labs will be required the use of Spyder IDE, so please install booth within your Anaconda environment.
#
# ![nav-tabs2.png](data:image/png;base64,...)

# %% [markdown]
# # Now, let's move to the actual lab..

# %% [markdown]
# ---
#
# ## **Exercise 1: create a new notebook**
# 1. Open Anaconda Navigator.
# 2. Launch Jupyter Notebool from the home menu.
# 3. Go to File → New and select "Notebook". This creates a new Jupyter Notebook file. (Alternatively, you can click the "+" icon to open a new Launcher, and create your Python 3 Notebook from there.)
# 4. Select the "Python 3" kernel.
# 5. Look in the file browser, right-click on "Untitled.ipynb" and click "rename." Change the
# name of the file to "`<your LastName_FirstName>-lab-1.ipynb`". (`<your LastName_FirstName>` should be your, uh, last name and first name.)
# 6. Change the first cell in your new notebook to the Markdown cell by clicking on the menu
# that says "Code" and selecting "Markdown".
# 7. Let's write some Markdown. Please copy and paste in that Markdown cell the following code and executing it with Shift-Enter (Modify the code with your information ✍):
#
#
# ```html
# <h1><center>SAT 4310 Advanced Scripting Programming </center></h1>
#
# <h1><center>Lab 1: Intro to Jupyter </center></h1>
#
#
# <h3>
# <font color='blue'>
#
# **Course Name** : SAT 4310 Advanced Scripting Programming
#
# **Semester**    : Fall 2023
#
# **Author**      : Your full name
#
# **Assignment**  : Lab X  (X will be replaced by the corresponding lab number)
#
# **Date**: mm/dd/yy
#
# </font>
# <h3>
# ````
#
# ---

# %% [markdown]
# ## Saving your work
#
# By default Jupyter Notebook should autosave your work. To check and make sure you have autosave on, you can go to `settings>autosave documents` and ensure that its checked. We still highly recomend you save freqently though! Sometimes the autosave won't occur when you want it! The save icon is the floppy icon.

# %% [markdown]
# ---
#
# ## **Exercise 2: Markdown**
#
# Just for reference, here's a [Markdown cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet).
#
#
# 1. Create a new Markdown cell and put the following text at the top:
# `## Markdown Exercises`
# 2. Write a paragraph of text that answers the following questions. Include some **bold** and *italic* text.
#     * Why are you or are you not interested in learning to code?
#     * What do you hope being able to program will enable you to do?
#     * Make a Markdown list of 3 things you'd like to learn from this course.
#
# During your writing, feel free to use other Markdown styles or test out anything fancy, like writing HTML!

# %% [markdown]
# ---
#
# ## **Exercise 3: Just a bit more of Markdown**
#
# 1. Create a new Markdown cell.
# 2. Now visit https://giphy.com/ and find an animated gif that represents how you feel at this
# moment. Click on the GIF, then click "Copy Link" and get the "GIF Link" from the page.
# 3. Use Markdown image notation to insert the GIF you found into the Markdown cell. (*Hint: it's a lot like link notation but more excited.*)
# 4. Create one more Markdown cell and insert the following text: `---`
#
# ---

# %%
print("Hi! I'm a code cell. Try changing me.")

# %% [markdown]
# ---
#
# ## **Exercise 4: executing code in the Jupyter Notebook**
#
# 1. Create a new Markdown cell with just the following text:
# `## Jupyter Notebook Exercises`
# 2. Create a new code cell, then copy the following Python code into the cell and execute it:
# `name = input(prompt="What is your name? ")`
# `print("Hello", name, "!")`
# 3. Create a Markdown cell underneath the code cell you just executed and describe in your
# own words what happened when you ran that code.
# 4. Create a new code cell and copy that same code into the new code cell. Try modifying
# the code and executing it to see what happens. (Don't worry about making any mistakes, we're just playing around.)
# 5. Create a Markdown cell underneath the code cell you just executed and describe what
# happened.
#     * What did you try and modify?
#     * Did you get an error or did it run successfully?

# %% [markdown]
# ---
#
# ## **Exercise 5: visualizing data in the Notebook**
#
# 1. Create a new code cell and copy the following code into the cell and execute it. (The code may take a bit of time to execute, don't worry.)
#
# ```python
# %matplotlib inline
# import pandas as pd
# # Load the PGH 311 Complaint data
# data_url = \
# "https://data.wprdc.org/datastore/dump/76fda9d0-69be-4dd5-8108-0de7907fc5a4"
# complaints = pd.read_csv(data_url, parse_dates=True, index_col="CREATED_ON")
# # Produce a graph that shows the number of complaints per month
# complaints.resample("M").size().plot();
# ```
#
# 2. Create a Markdown cell underneath the code cell you just executed and describe what
# you see. What do you think the data in this chart tell us?
# 3. Create a new Markdown cell, visit https://giphy.com/, and insert an gif into the Notebook
# that describes how you feel.

# %% [markdown]
# ---
#
# ## **Exercise 6: uploading your work**
#
# 1. Make sure your exercise notebook has the correct name: `<your LastName_FirstName>-lab-1.ipynb`. (You won't get credit for your hard work otherwise.)
# 2. Right-click on that notebook and click ↓Download. Download the file to your computer. (This varies depending on your device, but save it somewhere easily accessible.)
# 3. Open [Canvas](https://canvas.pitt.edu) and log in.
# 4. Go to the assignment for this week, hit submit, and upload your lab from your computer.
#
# ---
#
# Good job, and see you next week.

# %% [markdown]
# ![jeff](https://media.giphy.com/media/l0Ex8rGSELsb7SEz6/giphy.gif)
