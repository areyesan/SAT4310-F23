# %% [markdown]
# <h1><center>SAT 4310 Advanced Scripting Programming </center></h1>
#
# <h1><center>Lab 1: Python Basics </center></h1>
#
#
#
# <h3>
# <font color='blue'>
#
# **Course Name** : SAT 4310 Advanced Scripting Programming
#
# **Semester**    : Fall 2023
#
# **Author**      : Your full name
#
# **Assignment**  : Lab X  (X will be replaced by the corresponding lab number)
#
# **Date**: mm/dd/yy
#
# </font>
# <h3>

# %% [markdown]
# ### In this lab exercise, you will be practicing Python basics that cover strings, numbers, operators, and arrays.
# ### Provide your solution under each of the following problems,  and submit this _notebook_ includes your source code.

# %% [markdown]
# ## **Exercise  1:  Given a string named str_mtu = "Michigan Technological University is a flagship public research university.", using string slicing to exract the first two words and last one word, and then merge them. Display the merged string.**
# ```
# Michigan Technological university.
# ```

# %% [markdown]
# ## **Exercise  2: Remove first 21 characters from a string called my_str, if the character is 'i'**
# my_str = "Michigan Technological University is a flagship public research university founded in 1885. Our campus in Michigan’s Upper Peninsula overlooks the Keweenaw Waterway and is just a few miles from Lake Superior."
#
# ```
# Michigan Technological
# Mchgan Technologcal
# ```

# %% [markdown]
# ## **Exercise 3: Create a 2D Numpy Array.**
# We can use the attribute ```ndim``` to obtain the number of axes or dimensions referred to as the rank. Attribute ```shape``` returns a tuple corresponding to the size or number of each dimension. The total number of elements in the array is given by the attribute ```size```.
#
# Create a 2D Numpy Array, and use the ```ndim, shape```, ```size``` attribute to provide the dimension, the shape and the size of the array.
#
# ```
# A:
#  [[5 2 3]
#  [4 6 2]
#  [5 8 9]]
#
# This is the dimension of A:  2
# This is the shape of A:  (3, 3)
# This is the size of A:  9
# ```

# %% [markdown]
# ## **Exercise 4: Accessing different elements of a Numpy Array**
# Given the following Array:
# ```python
# B = np.array([[11, 12, 13], [21, 22, 23], [31, 32, 33]])
# ```
# Use indexing to access and print the elements specified in the following figures:
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
#
# ```
# Element(s) from first image:  23
# Element(s) from second image:  11
# Element(s) from third image:  [11 12]
# Element(s) from fourth image:  [13 23]
# ```

# %% [markdown]
# ## **Exercise 5: Array's Basic Operations.**
# Given the following Arrays:
# ![image.png](data:image/png;base64,...)
#
# Prease, perform the following operations:
#
# $$X+Y$$
# $$3Y$$
# $$Y^{-1}$$
# $$X^{T}$$
#
# ```
# X=
#  [[1 0]
#  [0 1]]
#
# Y=
#  [[2 1]
#  [1 2]]
#
# X+Y=
#  [[3 1]
#  [1 3]]
#
# 3*Y=
#  [[6 3]
#  [3 6]]
#
# Y^-1=
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
#
# X^T=
#  [[1 0]
#  [0 1]]
# ```

# %% [markdown]
# ## **Exercise 6: Given matrices $ A \in \mathbb{R}^{4\times2}$ and $B \in \mathbb{R}^{4\times2}$**
# ![image.png](data:image/png;base64,...)
#
# Compute the following using python programming:
# $$A*B^T$$
# $$A+B$$
# $$A-B$$
#
# hint: use the ```dot``` function for matrix multiplication
#
# ```
# A=
#  [[22 43]
#  [12 60]
#  [23 14]
#  [10 16]]
#
# B=
#  [[2 3]
#  [1 0]
#  [2 4]
#  [1 6]]
#
# A*B^T=
#  [[173  22 216 280]
#  [204  12 264 372]
#  [ 88  23 102 107]
#  [ 68  10  84 106]]
#
# A+B=
#  [[24 46]
#  [13 60]
#  [25 18]
#  [11 22]]
#
# A-B=
#  [[20 40]
#  [11 60]
#  [21 10]
#  [ 9 10]]
# ```

# %% [markdown]
# ## **Exercise 7: For the above matrices A and B, perform matrix multiplication using ```dot``` function.**
# Is there any error? if so, briefly explain why

# %% [markdown]
# ## **Exercise 8: For the above matrices A and B, compute and print their individuals traces.**
#
# ```
# A=
#  [[22 43]
#  [12 60]
#  [23 14]
#  [10 16]]
#
# B=
#  [[2 3]
#  [1 0]
#  [2 4]
#  [1 6]]
#
# Trace of A=82
# Trace of B=2
# ```

# %% [markdown]
# ---
#
# ## **Exercise 9: uploading your work**
#
# 1. Make sure your exercise notebook has the correct name: `<your LastName_FirstName>-lab-1.ipynb`. (You won't get credit for your hard work otherwise.)
# 2. Right-click on that notebook and click ↓Download. Download the file to your computer. (This varies depending on your device, but save it somewhere easily accessible.)
# 3. Open [Canvas](https://mtu.instructure.com/) and log in.
# 4. Go to the assignment for this week, hit submit, and upload your lab from your computer.
#
# ---
#
# Good job, and see you next week.
